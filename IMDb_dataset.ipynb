# %%
import pandas as pd
import os

# %%
data_path = os.path.join(os.getcwd(), 'data', 'IMDb','part-01.json')
df = pd.read_json(data_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010293 entries, 0 to 1010292
# Data columns (total 9 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   review_id       1010293 non-null  object
#  1   reviewer        1010293 non-null  object
#  2   movie           1010293 non-null  object
#  3   rating          958773 non-null   float64
#  4   review_summary  1010293 non-null  object
#  5   review_date     1010293 non-null  object
#  6   spoiler_tag     1010293 non-null  int64
#  7   review_detail   1010293 non-null  object
#  8   helpful         1010293 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 69.4+ MB

# %%
df.head()
# Out:
#    review_id         reviewer                          movie  rating  \
# 0  rw5704482    raeldor-96879            After Life (2019– )     9.0
# 1  rw5704483          dosleeb  The Valhalla Murders (2019– )     6.0
# 2  rw5704484  brightconscious           Special OPS (2020– )     7.0
# 3  rw5704485       gasconyway              #BlackAF (2020– )     8.0
# 4  rw5704487     mmason-15867             The Droving (2020)     2.0
#
#           review_summary review_date  spoiler_tag  \
# 0   Very Strong Season 2  3 May 2020            0
# 1  Icelandic detectives?  3 May 2020            0
# 2        Nothing special  3 May 2020            0
# 3               Good but  3 May 2020            0
# 4       An honest review  3 May 2020            0
#
#                                        review_detail   helpful
# 0  I enjoyed the first season, but I must say I t...    [1, 1]
# 1  I know Iceland is a small country and police d...    [2, 2]
# ...

# %% [markdown]
# __Output a review_datail:__

# %%
df.review_detail[0]
# Out:
# "I enjoyed the first season, but I must say I think season 2 is even stronger. Ricky does a great job as both writer, actor and director and brings out the best in a superb supporting cast. If there was one thing I'd change, I'd like to hear him talk about himself less with other people and speak more in the third person, but other than that it's pretty hard to fault this funny yet emotional comedy."

# %% [markdown]
# __Find reviews for a specific movie:__

# %%
movie_reviews = df.loc[df["movie"]=='After Life (2019– )'].copy()

# %%
movie_reviews
# Out:
#         review_id               reviewer                movie  rating  \
# 0       rw5704482          raeldor-96879  After Life (2019– )     9.0
# 26      rw5704512             lizadeegan  After Life (2019– )    10.0
# 35      rw5704521            NinnaMali97  After Life (2019– )     9.0
# 87      rw5704579  dimitardimitrov-47886  After Life (2019– )    10.0
# 96      rw5704588             josh-29279  After Life (2019– )    10.0
# ...           ...                    ...                  ...     ...
# 957553  rw6420592            phillipoaks  After Life (2019– )    10.0
# 958836  rw5392266             michelle71  After Life (2019– )     8.0
# 965772  rw5395638            lialumbriga  After Life (2019– )    10.0
# 979505  rw6437958         ianhuntercowan  After Life (2019– )     8.0
# 980573  rw6439175              ergunbuse  After Life (2019– )    10.0
#
#                          review_summary       review_date  spoiler_tag  \
# ...

# %% [markdown]
# __Sort these reviews in ascending order:__

# %%
movie_reviews = movie_reviews.sort_values('rating',ascending=False)
movie_reviews
# Out:
#         review_id          reviewer                movie  rating  \
# 980573  rw6439175         ergunbuse  After Life (2019– )    10.0
# 207822  rw5536353            FlowXP  After Life (2019– )    10.0
# 723676  rw6146509     kenrick-fearn  After Life (2019– )    10.0
# 169907  rw5728614      amanda-25351  After Life (2019– )    10.0
# 179545  rw5730459           eldehag  After Life (2019– )    10.0
# ...           ...               ...                  ...     ...
# 162148  rw5727734   kindfiercebrave  After Life (2019– )     2.0
# 733653  rw6369123  upinthesky-53426  After Life (2019– )     1.0
# 528120  rw5781642      skheirdastan  After Life (2019– )     1.0
# 469678  rw5773038             znwch  After Life (2019– )     1.0
# 31327   rw5709396             ben06  After Life (2019– )     1.0
#
#                                            review_summary       review_date  \
# 980573                                            Awesome    3 January 2021
# ...

# %%
# 找到第三个用户的review
movie_reviews.iloc[2].review_detail
# Out:
# "I feel not since the UK version of the The Office has RG's study of life had more meaning. This series is full of pure and raw emotion - it's ability to tap into the innerself and the ensuing conflict of feelings during a period of loss is incredible. I am in a very long and happy marriage and I often contemplate how I would react if my spouse was taken from me either through illness or an unexpected event and I can see myself reacting somewhat like the main character excellently portrayed by Ricky Gervais. I am not sure it would be a suitable post-bereavement therapy ...but after some time had passed perhaps it would actually help some people come to terms in a small way to their loss. The mixture of sadness and laughable circumstances, his criticisms and observations on society as whole has been nailed down to tee. Bravo Mr Gervais your best work to date and long may your creative genius continue - deffo a 11 out of 10 ."

# %% [markdown]
# __review_date是一个str，如果要按照日期排序要自己写方法（比如把string“3 January 2021”替换成int“20210103”）:__

# %%
type(movie_reviews.review_date[0])
# Out:
# str
